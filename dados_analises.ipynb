# %% [markdown]
# <a href="https://colab.research.google.com/github/laryscampark/emd-desafio-junior-data-scientist/blob/feature%2FEMD-DESAFIO-JUNIOR-DATA-SCIENTIST-Laryssa/dados_analises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import basedosdados as bd
import pandas as pd

# %%
! pip install basedosdados

# %%
import basedosdados as bd

query = '''
SELECT COUNT (*) AS total_chamados
FROM `datario.administracao_servicos_publicos.chamado_1746`
WHERE data_particao = '2023-04-01'
'''
df = bd.read_sql(query, billing_project_id="projeto-dados-rio")

df.head()
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  6.18rows/s]
#    total_chamados
# 0           65938

# %%
query = '''
SELECT COUNT(*) AS total_chamados_sem_bairro
FROM `datario.administracao_servicos_publicos.chamado_1746` c
LEFT JOIN `datario.dados_mestres.bairro` b ON c.id_bairro = b.nome_regiao_planejamento
WHERE data_particao = '2023-04-01' AND (b.id_bairro IS NULL OR b.nome_regiao_planejamento = '')
'''
df = bd.read_sql(query, billing_project_id="projeto-dados-rio")

df.head()
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  6.02rows/s]
#    total_chamados_sem_bairro
# 0                      65938

# %%
query = '''
SELECT * FROM `datario.administracao_servicos_publicos.chamado_1746`  LIMIT 10
'''
df = bd.read_sql(query, billing_project_id="projeto-dados-rio")

df.head(5)

# %%
query = '''
SELECT * FROM `datario.dados_mestres.bairro` LIMIT 10
'''
df = bd.read_sql(query, billing_project_id="projeto-dados-rio")

df.head(5)

# %%
query = '''
SELECT COUNT(*) AS total_chamados
FROM `datario.administracao_servicos_publicos.chamado_1746` c
JOIN `datario.dados_mestres.bairro` b ON c.id_bairro = b.nome_regiao_planejamento
WHERE data_particao = '2023-04-01'
'''

dados_consultados = bd.read_sql(query, billing_project_id="projeto-dados-rio")

dados_consultados.head()
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  5.48rows/s]
#    total_chamados
# 0               0

# %%
query = '''
SELECT tipo, COUNT(*) AS total
FROM `datario.administracao_servicos_publicos.chamado_1746`
WHERE data_particao = '2023-04-01'
GROUP BY tipo
ORDER BY total DESC
LIMIT 1
'''

dados_consultados = bd.read_sql(query, billing_project_id="projeto-dados-rio")

dados_consultados.head()
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  6.41rows/s]
#                        tipo  total
# 0  Estacionamento Irregular  10256

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'Data': ['01/04/2023'], 'Total de Chamados': [123]})


plt.figure(figsize=(8, 6))
plt.bar(df['Data'], df['Total de Chamados'], color='skyblue')
plt.xlabel('Data')
plt.ylabel('Total de Chamados')
plt.title('Número de Chamados Abertos em 01/04/2023')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
